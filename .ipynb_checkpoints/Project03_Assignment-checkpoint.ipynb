# %% [markdown]
# ### INST326 OOP Project 03

# %% [markdown]
# Rename this notebook, replacing "_Assignment" with "_YourName"<br>
# Insert Signature Block Here

# %% [markdown]
# ### The Project
# Everyone will do the same project this time. This is a group project, so you must work in your assigned groups. Include the link to your group's GitHub repository (one link per group). Use comments in your code to document your solution. If you need to write comments to the grader, add a markdown cell immediately above your code solution and add your comments there. Be sure to read and follow all the requirements and the Notebook Instructions at the bottom of this notebook. Your grade may depend on it!

# %% [markdown]
# #### 1. A Scheduling Program
# >  My wife is responsible for scheduling caregivers for her 93 year-old mother. Currently she writes out the schedule on a monthly calendar and photocopies it for everyone. I want all of you to help me write a program to help her with scheduling. While this is a specific application, this program will be broadly useful and adaptable to any scheduling needs for small businesses, clubs, and more.

# %% [markdown]
# #### Requirements
# >  Care is required 12 hours per day, 7 days a week. There are two shifts each day: 7:00 AM - 1:00 PM, and 1:00 PM to 7:00 PM. There are a total of 8 caregivers. Some are family members and some are paid. Each caregiver has their own availability for shifts that is generally the same from month to month, but there are exceptions for work, vacations, and other responsibilities. Your program should do the following:
# > 1. Manage caregivers and their schedules. Attributes include: name, phone, email, pay rate, and hours.
# > 2. Each caregiver should have their own availability schedule where they can indicate their availability for each shift. Availability categories are 'preferred', 'available' (default), and 'unavailable'.
# > 3. Create a care schedule that covers AM and PM shifts and displays caregiver names on a calendar (see example). The schedule should accomodate caregivers' individual schedules and availability preferences. The python calendar module provides options for creating HTML calendars. Sample code for the HTML calendar is in the project folder.
# > 4. Paid caregivers are paid weekly at $20/hr. Your program should calculate weekly pay based on assigned hours. Provide a separate pay report that lists weekly (gross: hours x rate) amounts to each caregiver, along with weekly and monthly totals. The report can be a text document, or presented in GUI or HTML format.

# %% [markdown]
# #### Group Requirements
# >  1. Your submitted project should follow OOP principles like abstraction, encapsulation, inheritance, and polymorphism as appropriate. Your program should use classes.
# >  2. Select a group leader who will host the group's project repository on their GitHub.
# >  3. Create the group repository and add a main program document. See example.
# >  4. Create branches off the main program for each group member, and assign part of the program to each member.
# >  5. Each member should work on their branch.
# >  6. When each member is finished, merge the branches back into the main program. You may use 'merge' or 'pull requests', your choice.
# >  7. iterate and debug as necessary.

# %% [markdown]
# #### Working with HTML
# > Since this is a course on python, not HTML, you are not expected to know HTML. Therefore, you may copy applicable portions of the sample code or use AI to write the HTML portions of your application. Ypu should write the main python code yourself.

# %% [markdown]
# #### What you need to turn in
# >  This is a group project. There will be one submission per group. Your submission will be graded as a group.
# >  1. Include your group number and the names of all group members in the signature block at the top of this notebook.
# >  2. In the cell below, paste the link to your project repository. One link per group. The grader will review the activity and history provided by GitHub. To add a hyperlink to a Jupyter markdown cell, follow the instructions in the cell below.
# >  3. Below the GitHub Repository Link cell is a code cell. Copy and paste your final program code into this cell.

# %% [markdown]
# #### GitHub Repository Link
# > Example: [INST326_Fall2024/Projects/Project03](https://github.com/sdempwolf/INST326_Fall_2024/tree/main/Projects/Project03)
# >
# > Edit the link code below with your information, then run this cell. Test the link! It should take you to your GitHub project repository.
# > [external link text](http://url_here)

# %%
# Solution - enter your code solution below
import tkinter as tk
from tkinter import StringVar, ttk

class Caregiver:
    def __init__(self, name, phone, email, payRate = 20, hours = 0):
        self.__name = name
        self.__phone = phone
        self.__email = email
        self.__payRate = payRate
        self.__hours = hours

    # Getters
    def getName(self):
        return self.__name
    def getPhone(self):
        return self.__phone
    def getEmail(self):
        return self.__email
    def getPayRate(self):
        return self.__payRate
    def getHours(self):
        return self.__hours
    
    # Setters
    def setPhone(self, phone):
        self.__phone = phone
    def setEmail(self, email):
        self.__email = email
    def setPayRate(self, payRate):
        # conditional statement to get the pay rate
        if payRate >= 0:
            self.__payRate = payRate
        else:
            print("Pay must be greater than 0")
    def setHours(self, hours):
        # another conditonal for the hours
        if hours >= 0:
            self.__hours = hours
        else:
            print("Hours can't be less than 0")

    # Calculate Weekly Pay
    def weeklyPay(self):
        return self.__hours * self.__payRate

    # Display caregiver details
    def infoDisplay(self):
        return (f"Name: {self.__name}\n"
                f"Phone: {self.__phone}\n"
                f"Email: {self.__email}\n"
                f"Pay Rate: ${self.__payRate:.2f}/hr\n"
                f"Hours Worked: {self.__hours} hrs\n")

class caregiverManager:
    def __init__(self):
        self.caregivers = []
    def addCaregiver(self, caregiver):
        self.caregivers.append(caregiver)
    def removeCaregiver(self, name):
        self.caregivers = [cg for cg in self.caregivers if cg.getName() != name]
    def findCaregiver(self, name):
        for cg in self.caregivers:
            if cg.getName() == name:
                return cg
        return None
    
    def display_all_caregivers(self):
        if not self.caregivers:
            return "No available caregivers"
        else:
            return "\n".join(cg.infoDisplay() + "-" * 30 for cg in self.caregivers)
        
class Caregiver:
    def __init__(self, name, phone, email):
        self.__name = name
        self.__phone = phone
        self.__email = email
        # Availability dictionary for each day of the week and shift (AM/PM)
        self.__availability = {day: {"AM": "unavailable", "PM": "unavailable"} for day in ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]}
    
    # Set availability for a specific day and shift
    def setAvailability(self, day, shift, category):
        if day in self.__availability and shift in self.__availability[day]:
            if category in ["preferred", "available", "unavailable"]:
                self.__availability[day][shift] = category
            else:
                print(f"Invalid category {category}. Please use 'preferred', 'available', or 'unavailable'.")
        else:
            print(f"Invalid day or shift: {day} {shift}.")
    
    # Get the availability for the caregiver
    def getAvailability(self):
        return self.__availability
    
    # Get the name of the caregiver
    def getName(self):
        return self.__name


class CareSchedule:
    def __init__(self):
        # Weekly schedule with AM and PM shifts for each day
        self.schedule = { 
            "Mon": {"AM": None, "PM": None},
            "Tue": {"AM": None, "PM": None},
            "Wed": {"AM": None, "PM": None},
            "Thu": {"AM": None, "PM": None},
            "Fri": {"AM": None, "PM": None},
            "Sat": {"AM": None, "PM": None},
            "Sun": {"AM": None, "PM": None}
        }
        self.caregivers = []

    def addCaregiver(self, caregiver):
        self.caregivers.append(caregiver)
    
    # Assign caregivers based on availability
    def assignShifts(self):
        for day in self.schedule:
            for shift in self.schedule[day]:
                # Filter caregivers based on availability for that shift
                available_caregivers = [cg for cg in self.caregivers if cg.getAvailability()[day][shift] != "unavailable"]
                
                if available_caregivers:
                    # Sort caregivers: give preference to 'preferred', then 'available'
                    sorted_caregivers = sorted(
                        available_caregivers, 
                        key=lambda cg: {"preferred": 0, "available": 1, "unavailable": 2}.get(cg.getAvailability()[day][shift], 2)
                    )
                    # Assign the caregiver with the highest preference
                    self.schedule[day][shift] = sorted_caregivers[0].getName()
                else:
                    self.schedule[day][shift] = "No caregiver available"
    
    # Display the schedule
    def displaySchedule(self):
        display_str = "Caregiver Schedule:\n"
        for day, shifts in self.schedule.items():
            display_str += f"{day}:\n"
            for shift, caregiver in shifts.items():
                display_str += f"  {shift}: {caregiver}\n"
        return display_str
    
    def generatePayReport(self):
        report = "Weekly Pay Report:\n"
        report += "-" * 30 + "\n"
        total_weekly_pay = 0

        for caregiver in self.caregivers:
            weekly_pay = caregiver.weeklyPay()
            total_weekly_pay += weekly_pay
            report += f"{caregiver.getName()}: ${weekly_pay:.2f} (Hours: {caregiver.getHours()})\n"
        report += "-" * 30 + "\n"
        report += f"Total Weekly Pay: ${total_weekly_pay:.2f}\n"
        report += f"Total Monthly Pay (4 weeks): ${total_weekly_pay * 4:.2f}\n"

        return report


class App:
    def __init__(self, window):
        self.window = window
        self.window.title("Caregiver Schedule")
        self.window.geometry("1000x1000")

        self.schedule = []
        self.manager = caregiverManager()
        self.schedule_manager = CareSchedule()
        self.widgets()

    def addToSchedule(self):
        # Get inputs
        name = self.textbox.get().strip()
        phone = self.textbox.get().strip()
        email = self.textbox.get().strip()
        day = self.default1.get()
        time = self.default2.get()

        # Validate inputs
        if not name or day == "Select a day" or time == "Select a time":
            self.status_label.config(text="Please fill all fields.", fg="red")
            return

        # Add to schedule
        self.schedule.append((name, day, time))
        self.updateCalendar()
        self.status_label.config(text="Schedule updated!", fg="green")

        # Clear inputs
        self.textbox.delete(0, tk.END)
        self.textbox.delete(0, tk.END)
        self.textbox.delete(0, tk.END)
        self.default1.set("Select a day")
        self.default2.set("Select a time")

    def updateCalendar(self):
        for row in self.calendar.get_children():
            self.calendar.delete(row)

        for idx, (name, day, time) in enumerate(self.schedule, start=1):
            self.calendar.insert("", "end", values=(idx, name, day, time))
    def generatePayReport(self):
        report = self.schedule_manager.generatePayReport()
        self.payReportText.delete(1.0, tk.END)
        self.payReportText.insert(tk.END, report)

        with open("pay_report.txt", "w") as file:
            file.write(report)

        self.status_label.config(text="Pay report generated and saved to 'pay_report.txt'.", fg="green")
    
    def widgets(self):
       self.frame1 = tk.Frame(self.window)
       self.frame1.pack()
       
       self.label_name = tk.Label(self.frame1, text="Enter your name: ")
       self.label_name.pack(side="left", padx=5)
       
       self.textbox_name = tk.Entry(self.frame1)
       self.textbox_name.pack(side="left", padx=10)
       
       self.frame2 = tk.Frame(self.window)
       self.frame2.pack(pady=10)
       
       self.label_phone = tk.Label(self.frame2, text="Enter your phone number: ")
       self.label_phone.pack(side="left", padx=5)
       
       self.textbox_phone = tk.Entry(self.frame2)
       self.textbox_phone.pack(side="left", padx=10)
       
       self.label_email = tk.Label(self.frame2, text="Enter your email: ")
       self.label_email.pack(side="left", padx=5)
       
       self.textbox_email = tk.Entry(self.frame2)
       self.textbox_email.pack(side="left", padx=10)
       
       self.frame3 = tk.Frame(self.window)
       self.frame3.pack(pady=10)
       
       self.default1 = StringVar()
       self.default1.set("Select a day")
       self.days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
       self.dropdown1 = tk.OptionMenu(self.frame3, self.default1, *self.days)
       self.dropdown1.pack(pady=20)
       
       self.default2 = StringVar()
       self.default2.set("Select a time")
       self.hours = ["7:00 AM - 1:00 PM", "1:00 PM - 7:00 AM"]
       self.dropdown2 = tk.OptionMenu(self.frame3, self.default2, *self.hours)
       self.dropdown2.pack(pady=20)

       self.button = tk.Button(self.frame3, text="Add to Schedule", command=self.addToSchedule)
       self.button.pack(pady=10)

       self.generateReportButton = tk.Button(self.window, text="Generate Pay Report", command=self.generatePayReport)        self.generateReportButton.pack(pady=5)

       self.status_label = tk.Label(self.window, text="", fg="green")
       self.status_label.pack(pady=5)

       self.frame4 = tk.Frame(self.window)
       self.frame4.pack(pady=10, padx=20, fill="both", expand=True)

       columns = ("#", "Name", "Day", "Time")
       self.calendar = ttk.Treeview(self.frame4, columns=columns, show="headings", height=10)

       self.calendar.heading("#", text="#")
       self.calendar.heading("Name", text="Name")
       self.calendar.heading("Day", text="Day")
       self.calendar.heading("Time", text="Time")

       self.calendar.pack(fill="both", expand=True)

       self.payReportText = tk.Text(self.window, height=10, width=50)
       self.payReportText.pack(pady=10)
       
if __name__ == "__main__":
    window = tk.Tk()
    app = App(window)
    window.mainloop()
# Out:
# Caregiver Schedule:
# Mon:
#   AM: Alice
#   PM: Alice
# Tue:
#   AM: Alice
#   PM: Bob
# Wed:
#   AM: Charlie
#   PM: Alice
# Thu:
#   AM: No caregiver available
#   PM: Charlie
# Fri:
#   AM: No caregiver available
#   PM: No caregiver available
# Sat:
#   AM: No caregiver available
#   PM: No caregiver available
# Sun:
#   AM: No caregiver available
#   PM: No caregiver available

# %% [markdown]
# ### Notebook Instructions
# > Before turning in your notebook:
# > 1. Make sure you have renamed the notebook file as instructed
# > 2. Make sure you have included your signature block and that it is correct according to the instructions
# > 3. comment your code as necessary
# > 4. run all code cells and double check that they run correctly. If you can't get your code to run correctly and you want partial credit, add a note for the grader in a new markdown cell directly above your code solution.<br><br>
# Turn in your notebook by uploading it to ELMS<br>
# IF the exercises involve saved data files, put your notebook and the data file(s) in a zip folder and upload the zip folder to ELMS
